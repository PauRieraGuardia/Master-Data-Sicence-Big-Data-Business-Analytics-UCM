# %% [markdown]
# ## 1. Datos vehículos a la venta 2016 en UK
#
# Proposito:
#
# * facilitar la lectura del .csv que contiene los datos de este ejemplo

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import plotnine
from plotnine import *

# %% [markdown]
# ### Carga de datos

# %%
df = pd.read_pickle('datos_vehiculos_2016_UK.pkl')

# %%
df.shape
# Out:
# (4490, 20)

# %%
df.describe(include='all')
# Out:
#        Manufacturer  Model  EngineCapacity FuelType  MetricUrbanCold  \
# count          4490   4490     4490.000000     4490      4459.000000
# unique           44    450             NaN        7              NaN
# top             BMW  Coupe             NaN   Diesel              NaN
# freq            607    260             NaN     2274              NaN
# mean            NaN    NaN     1991.111804      NaN         6.925252
# std             NaN    NaN      828.057573      NaN         2.800404
# min             NaN    NaN      647.000000      NaN         0.000000
# 25%             NaN    NaN     1499.000000      NaN         5.200000
# 50%             NaN    NaN     1968.000000      NaN         6.100000
# 75%             NaN    NaN     1997.000000      NaN         7.700000
# max             NaN    NaN     6752.000000      NaN        25.600000
#
#         MetricExtraUrban  MetricCombined  ImperialUrbanCold  \
# count        4459.000000     4490.000000        4459.000000
# ...

# %%
count_classes = pd.value_counts(df['Tipo'],sort=True)
count_classes.plot(kind='bar', rot=0)
plt.title('Tipos de vehículos UK 2016')
plt.xlabel('Tipo')
plt.ylabel('Frecuancia')
# Out:
# C:\Users\pauri\AppData\Local\Temp\ipykernel_18892\2531698899.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# Text(0, 0.5, 'Frecuancia')

# %%
plt.scatter(df['EngineCapacity'],
            df['MetricCombined'])

plt.xlabel('Tamaño motor (cm3)')
# Out:
# Text(0.5, 0, 'Tamaño motor (cm3)')

# %% [markdown]
# ### 2. Visualizaciones con ggplot
#
# Además del contenido recogido en la docu. teórica, es aconsejable segur este excelente (y práctico) tutorial:
#
# https://realpython.com/ggplot-python

# %%
( ggplot(data=df) 
 + aes(x = 'EngineCapacity',
     y = 'MetricCombined')
) # Nos nos dara una forma puesto que no le hemos dado una geometria

# %%
( ggplot(data=df) 
 + aes(x = 'EngineCapacity',
     y = 'MetricCombined')
+ geom_point() # puntos
)

# %%
( ggplot(data=df) 
 + aes(x = 'EngineCapacity',
     y = 'MetricCombined')
+ geom_smooth() # linea de tendencia
)

# %%
( ggplot(data=df) 
 + aes(x = 'EngineCapacity',
     y = 'MetricCombined')
+ geom_point() # grafico de puntos
+ geom_smooth() # linea de tendencia
)

# %%
mi_grafico =( ggplot(data=df) 
 + aes(x = 'EngineCapacity',
     y = 'MetricCombined'))

# %%
mi_grafico

# %%
# le podemos añadir capas con nuestro grafico definido
mi_grafico + geom_point() + geom_smooth()

# %%
( ggplot(data=df) 
 + aes(x = 'EngineCapacity',
     y = 'MetricCombined',
     color = 'Tipo') # que variable usamos para darle color
+ geom_point() # grafico de puntos

)

# %%
( ggplot(data=df) 
 + aes(x = 'EngineCapacity',
     y = 'MetricCombined',
     color = 'Tipo') # que variable usamos para darle color
+ geom_point() # grafico de puntos
+ geom_smooth()

)

# %%
( ggplot(data=df) 
 + aes(x = 'EngineCapacity',
     y = 'MetricCombined',
     color = 'CO2gkm') # que variable usamos para darle color
+ geom_point() # grafico de puntos

)

# %%
( ggplot(data=df) 
 + aes(x = 'EngineCapacity',
     y = 'MetricCombined',
     color = 'CO2gkm') # que variable usamos para darle color
+ geom_density_2d() # Grafico de densidad 

)

# %%
import sklearn
import skmisc

# %%
( ggplot(data=df) 
 + aes(x = 'EngineCapacity',
     y = 'MetricCombined',
     color = 'Tipo') 
+ geom_point(alpha=0.1) 
+ geom_smooth(method='lm') # Muestra modelo lineal

)

# %%
( ggplot(data=df) 
 + aes(x = 'EngineCapacity',
     y = 'MetricCombined',
     color = 'Tipo') 
+ geom_point(alpha=0.1) 
+ geom_smooth(method='lowess') # muestra variaciones no lineales del todo
)
# Out:
# c:\Users\pauri\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotnine\stats\smoothers.py:345: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# c:\Users\pauri\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotnine\stats\smoothers.py:345: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# c:\Users\pauri\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotnine\stats\smoothers.py:345: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.

# %%
g = ( ggplot(data=df) 
 + aes(x = 'EngineCapacity',
     y = 'MetricCombined',
     color = 'CO2gkm') 
+ geom_point(alpha=0.1) 
+ geom_smooth(method='lm') # Muestra modelo lineal
+ geom_smooth(method='lowess')
)

# %%
g = g + theme(figure_size=(12,12)) # damos un tamaño a la figura redefiniendo g

# %%
# llamamos a g
g
# Out:
# c:\Users\pauri\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotnine\stats\smoothers.py:345: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.

# %%
g.save('pimer_scatterplot.png',dpi=600) # Para guardar el grafico como png
# Out:
# c:\Users\pauri\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotnine\ggplot.py:630: PlotnineWarning: Saving 12 x 12 in image.
# c:\Users\pauri\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotnine\ggplot.py:631: PlotnineWarning: Filename: pimer_scatterplot.png
# c:\Users\pauri\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotnine\stats\smoothers.py:345: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.

# %%
( ggplot(df) 
 + aes(x = 'EngineCapacity',
     y = 'MetricCombined',
     color = 'Tipo') 
+ geom_smooth(method='lowess')
+ geom_point()
+ facet_grid(cols='Tipo') # Aplciamos una columna de gráfico para cada uno
)
# Out:
# c:\Users\pauri\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotnine\stats\smoothers.py:345: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# c:\Users\pauri\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotnine\stats\smoothers.py:345: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# c:\Users\pauri\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotnine\stats\smoothers.py:345: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.

# %%
( ggplot(df) 
 + aes(x = 'EngineCapacity',
     y = 'MetricCombined',
     color = 'Tipo') 
+ geom_smooth(method='lowess')
+ geom_point()
+ facet_grid(rows='Tipo') # Aplciamos una fila de gráfico para cada uno
)
# Out:
# c:\Users\pauri\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotnine\stats\smoothers.py:345: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# c:\Users\pauri\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotnine\stats\smoothers.py:345: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# c:\Users\pauri\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotnine\stats\smoothers.py:345: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.

# %%
( ggplot(df) 
 + aes(x = 'Tipo',
     y = 'EmissionsNOxmgkm') 
+ geom_boxplot() # Grafico boxplot
)

# %%
( ggplot(df) 
 + aes(x = 'Tipo',
     y = 'EmissionsNOxmgkm') 
+ geom_boxplot()
+ coord_flip() # rotación del grafico
)

# %%
( ggplot(df) 
 + aes(x = 'Tipo',
     y = 'EmissionsNOxmgkm') 
+ geom_boxplot()
+ coord_flip() 
+ theme_classic() # temas del gráfico
)

# %%
( ggplot(df) 
 + aes(x = 'Tipo',
     y = 'EmissionsNOxmgkm') 
+ geom_boxplot()
+ coord_flip() 
+ geom_text(aes(label='Model'))
)
